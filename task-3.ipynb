# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import csv

# %%
def handleData(document):
    paperId = document['paperId']
    corpusId = document['corpusId']
    title_length = len(document['title'])
    title_length_without_space = len(document['title'].replace(' ', ''))
    title_length_in_words = len(document['title'].split())
    abstract_length = len(document['abstract'])
    abstract_length_without_space = len(document['abstract'].replace(' ', ''))
    abstract_length_in_words = len(document['abstract'].split())
    venue_length = len(document['venue'])
    venue_length_without_space = len(document['venue'].replace(' ', ''))
    venue_length_in_words = len(document['venue'].replace(' ', ''))
    #TODO: Xu ly them cac truong
    return {
        'paperId': paperId,
        #TODO: Tra ve object o day
    }

# %%
uri = "mongodb+srv://ductri0981:ductri123@semantic-scholar.okyqppw.mongodb.net/?appName=semantic-scholar"
# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)

#Get all data in mongoDB
database = client["sample_mflix"]
collection = database["users"]
documents = []
for document in collection.find():
    document = handleData(document)
    documents.append(document)

#TODO: chuyen mang object sang CSV o day
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
def handleData(document):
    paperId = document['paperId']
    corpusId = document['corpusId']
    title_length = len(document['title'])
    title_length_without_space = len(document['title'].replace(' ', ''))
    title_length_in_words = len(document['title'].split())
    abstract_length = len(document['abstract'])
    abstract_length_without_space = len(document['abstract'].replace(' ', ''))
    abstract_length_in_words = len(document['abstract'].split())
    venue_length = len(document['venue'])
    venue_length_without_space = len(document['venue'].replace(' ', ''))
    venue_length_in_words = len(document['venue'].replace(' ', ''))

# %%
def save_csv(documents: list[object]):
    with open('papers.csv', 'w', newline='') as csvfile:
        fieldnames = [
            'paperId', 
            'corpusId', 
            'title_length', 
            'title_length_without_space',
            'title_length_in_words',
            'abstract_length',
            'abstract_length_without_space',
            'abstract_length_in_words',
            'venue_length',
            'venue_length_without_space',
            'venue_length_in_words',
            'venue',
            'year',
            'referenceCount',
            'citationCount',
            'influentialCitationCount',
            'isOpenAccess',
            'fieldsOfStudy',
            's2FieldsOfStudy_count',
            'publicationTypes_count',
            'publicationDate',
            'journal_name',
            'author_count',
            'first_author_name',
            'embedding_dimension',
            'embedding_mean',
            'embedding_stddev'
        ]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(documents)
